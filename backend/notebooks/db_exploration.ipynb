# %% [markdown]
# # DB Exploration\n\nUtility notebook for quick DuckDB checks and cleanup while working on this project.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd()
if not (repo_root / 'backend').exists():
    repo_root = repo_root.parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from backend.db import session

# %%
print(f'Database path: {session.DB_PATH}')

# %%
tables = session.get_tables()
print(f'Found {len(tables)} tables:')
for table in tables:
    print(f'  - {table}')

# %%
result = session.execute_query("SELECT 'Hello from DuckDB!' AS message")
print(result[0][0])

# %%
confirm_drop = False

if confirm_drop:
    session.drop_all_tables()
else:
    print('Set confirm_drop = True to drop all tables.')
